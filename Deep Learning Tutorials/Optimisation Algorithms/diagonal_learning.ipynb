# %% [markdown]
# Looking into learning functions, let's visualize a really simple function -- where we just keep the values along a matrix diagonal stripe. We'll set up a bunch of random matrixes, and map those through just the diagonals of those matrixes.
#
# In order to see inside the learning process, and what the different learning functions actually do -- we'll inspect what is being learned with some animation. If all works out well, we'll 'learn' a diagonal mapping function!

# %%
import mxnet as mx
from mxnet import nd, autograd, gluon
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# This is our objective function -- we know what we are looking for, and much like solving an equation in good old algebra, we'll be using machine learning to figure out the answer. We'll take a look at it as an image.

# %%
size = 16 #image size of 16x16
batch_size = 32
objective = nd.ones(size).diag() #use numpy diagonal function to create a diagonal line
plt.imshow(objective.asnumpy(), cmap='binary') #this is our target

# %% [markdown]
# Now - a set of random inputs and outputs, including a data loader to dispense mini batches.

# %%
inputs = [nd.random.uniform(shape=(size, size)) for i in range(100*1024)] #100000 different samples with random distortion
outputs = [input * objective for input in inputs] #output is multiplied by objective function
dataset = mx.gluon.data.dataset.ArrayDataset(inputs, outputs) #data set
data_loader = mx.gluon.data.DataLoader(dataset, batch_size=batch_size) #data loader

# %% [markdown]
# Ok -- now let's look at what we've created -- some 'white noise' and then a nice extraction along the diagonal of that noise by multiplying the matrix.

# %%
plt.imshow(inputs[0].asnumpy(), cmap='binary')

# %% [markdown]
# And the output -- multiply that random input by our diagonal stripe -- and only the diagonal values from the random noise above remain. Notice it isn't all black pixels, but greys!

# %%
plt.imshow(outputs[0].asnumpy(), cmap='binary')

# %% [markdown]
# OK -- now we'll set up to learn, starting with a random matrix. This is again white noise, and we'll be using machine learning to adjust the values to get to our nice solid diagonal stripe objective function.
#
# We're setting up an MxNet parameter, not just an array, as we'll be using an optmizer to adjust these values -- machine learning!

# %%
#everything will be run on the CPU context, these are really simple models
ctx = mx.cpu()

params = gluon.parameter.ParameterDict('_')
learned_diagonal = params.get('learned_diagonal', grad_req='write', shape=(size, size))
params.initialize(ctx=ctx)
plt.imshow(learned_diagonal.data().asnumpy(), cmap='binary')

# %% [markdown]
# This is a really simple network - a single multiplication, with a square loss function. At each training epoch, we'll capture the value of the learned objective as a numpy array so we can take a look.

# %%
def net(input):
    return input * learned_diagonal.data()

def learn(net, optimizer):
    params.initialize(ctx=ctx, force_reinit=True)
    epochs = 10
    #initial value, so we can see where we started
    learning_steps = []
    learning_steps.append(learned_diagonal.data().asnumpy())
    #simple loss function
    square_loss = gluon.loss.L2Loss()
    losses = []
    for e in range(epochs):
        for input_batch, output_batch in data_loader:
            with autograd.record():
                predicted = net(input_batch)
                loss = square_loss(predicted, output_batch)
                loss.backward()
            optimizer.step(input_batch.shape[0])
        learning_steps.append(learned_diagonal.data().asnumpy())

        print("Loss: {0}".format(nd.sum(loss).asscalar()), flush=True)
        losses.append(nd.sum(loss).asscalar())
    return learning_steps, losses

# %% [markdown]
# And here is a function to make an animated bitmap of the learning. At each step, we are simply showing an image, and then joining it together with the `FuncAnimation` class.

# %%
def animate(frames):
    fig, ax = plt.subplots(figsize=(4, 4))

    def update(i):
        ax.imshow(frames[i], cmap='binary')
        ax.set_axis_off()

    anim = animation.FuncAnimation(fig, update, frames=len(frames), interval=200)
    plt.close()
    return HTML(anim.to_jshtml())

# %% [markdown]
# And now -- we can see -- the diagonal is emerging -- but there is still a lot of noise.

IEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAmK7+\
# NPPhw4dLu/Pnzzdvent7S7fOnTvXvHnyySdLt15++eXS7vjx482b6qeqH3744dJu/vz5zZuBgYHS\
# rbvuuqt5s3v37tKtadOmlXaXL19u3vT19ZVuVf7vAGPFExAQI0BAjAABMQIExAgQECNAQIwAATEC\
# BMQIEBAjQECMAAExAgTECBAQ09Vvw3/wwQel3bFjx5o3e/bsKd3atGlT82blypWlWxs2bCjtZsyY\
# 0bx57733Sreqb9E/+uijzZuRkZHSrUOHDjVvhoaGSrd27txZ2p04caJ5c+ONN5ZuVf+OY8ETEBAj\
# QECMAAExAgTECBAQI0BAjAABMQIExAgQECNAQIwAATECBMSMT/+Af3LDDTeUdlOnTm3enDx5snRr\
# zpw5zZtZs2aVbl26dKm027VrV/PmjjvuKN367rvvSrvnnnuueVN9gXjNmjXNm3vuuad068MPPyzt\
# br755ubNmTNnSreSPAEBMQIExAgQECNAQIwAATECBMQIEBAjQECMAAExAgTECBAQI0BAjAABMV39\
# aebDhw+Xdr29vc2bJUuWlG5t3bq1efPZZ5+VblU/6Txz5szmzenTp0u3br/99tJuxYoVzZubbrqp\
# dGvSpEnNm9tuu61069SpU6Xdtm3bmjePPPJI6da3335b2o0FT0BAjAABMQIExAgQE

# %% [markdown]
# Basically -- we didn't go far enough. SO we have a couple options with plain stochastic gradient descent -- we can:
# * learn more -- more data, more epochs
# * learn faster -- a higher learning rate
#
# We already know that more data helps learning, let's look at the effect of a faster learning rate.

# %%
optimizer = gluon.Trainer(params, 'sgd', {'learning_rate': 0.01})
learning_steps, losses = learn(net, optimizer)
animate(learning_steps)
# Out:
# Loss: 0.32408130168914795
# Loss: 0.2981913089752197
# Loss: 0.27436962723731995
# Loss: 0.25245100259780884
# Loss: 0.23228338360786438
# Loss: 0.2137269228696823
# Loss: 0.1966528743505478
# Loss: 0.18094277381896973
# Loss: 0.16648775339126587
# Loss: 0.15318752825260162
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img128cc89de0bd4c608e1385d17e3f8050">
#     <br>
#     <input id="_anim_slider128cc89de0bd4c608e1385d17e3f8050" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim128cc89de0bd4c608e1385d17e3f8050.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim128cc89de0bd4c608e1385d17e3f8050.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select128cc89de0bd4c608e1385d17e3f8050" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img128cc89de0bd4c608e1385d17e3f8050";
#     var slider_id = "_anim_slider128cc89de0bd4c608e1385d17e3f8050";
#     var loop_select_id = "_anim_loop_select128cc89de0bd4c608e1385d17e3f8050";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCw
# You can see right away the lower loss values -- and in the animation, a more clear diagonal emerges. Now -- this isn't a general answer to simply increase the learning rate, learning rate is what we call a *hyperparameter*, and you'll need to tune it in context of our problem.

# %% [markdown]
# In addition to the learning rate, there is another parameter -- momentum.

# %%
optimizer = gluon.Trainer(params, 'sgd', {'learning_rate': 0.01, 'momentum': 0.1})
learning_steps, losses = learn(net, optimizer)
animate(learning_steps)
# Out:
# Loss: 0.29732418060302734
# Loss: 0.2710551917552948
# Loss: 0.24710708856582642
# Loss: 0.22527487576007843
# Loss: 0.20537157356739044
# Loss: 0.18722674250602722
# Loss: 0.1706850826740265
# Loss: 0.15560491383075714
# Loss: 0.14185725152492523
# Loss: 0.12932398915290833
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img10282573bf994db4b4f88b9cf27a21a5">
#     <br>
#     <input id="_anim_slider10282573bf994db4b4f88b9cf27a21a5" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim10282573bf994db4b4f88b9cf27a21a5.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim10282573bf994db4b4f88b9cf27a21a5.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select10282573bf994db4b4f88b9cf27a21a5" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img10282573bf994db4b4f88b9cf27a21a5";
#     var slider_id = "_anim_slider10282573bf994db4b4f88b9cf27a21a5";
#     var loop_select_id = "_anim_loop_select10282573bf994db4b4f88b9cf27a21a5";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAACZBJREFUeJzt3d2LluUaxuF3svxKa1AjtTYa6EMM\
# SizI2ihEREyIjFJTwh2jNFEUKYIoosIgmCBIKTUqjCAM7GsYipQwMjc0kZHEIqGCEkLMomij3v6C\
# FtzXmtb5wjqO/ZNrUvn17Dzz9HW73W4HIOC89A8A/P8SICBGgIAYAQJiBAiIESAgRoCAGAECYgQI\
# iBEgIEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAGAECYgQIiBEgIEaAgBgBAmIECIgRICBG\
# gIAYAQJiBAiIESAgRoCAGAECYgQIiBEgIOb89A/wn8ycObO0Gx4ebt589tlnpVvvv/9+8+bxxx8v\
# 3broootKu82bNzdv9uzZU7p1yy23lHbnndf+/8IXXnihdOvIkSPNm0ceeaR0a86cOaXdwMBA8+a2\
# 224r3XrggQdKu9HgCQiIESAgRoCAGAECYgQIiBEgIEaAgBgBAmIECIgRICBGgIAYAQJi+rrdbjf9\
# Q/yTEydOlHazZ89u3qxZs6Z0a9KkSc2b6667rnTrrbfeKu2GhoaaN+vWrSvdGj9+fGm3fPny5s3P\
# P/9curVw4cLmzRVXXFG6Vd19++23zZutW7eWbq1YsaK0Gw2egIAYAQJiBAiIESAgRoCAGAECYgQI\
# iBEgIEaAgBgBAmIECIgRICCmp7+MumHDhtKu8jLq3r17S7dGRkaaN19//XXp1uDgYGl37733Nm/G\
# jh1bulX9EuisWbOaN+fOnSvd+uGHH5o3q1evLt2aP39+abds2bLmTQ+/V/6PPAEBMQIExAgQECNA\
# QIwAATECBMQIEBAjQECMAAExAgTECBAQI0BAjAABMT39aeapU6eWdp988knzZseOHaVbkydPbt48\
# +OCDpVtXX311aTdmzJjmTfUzv3v27CntKn8m27dvL93q7+9v3ixZsqR0a/HixaXd/v37mzcffvhh\
# 6dbu3btLu9HgCQiIESAgRoCAGAECYgQIiBEgIEaAgBgBAmIECIgRICBGgIAYAQJievrTzGfOnCnt\
# tm3b1rw5duxY6dYrr7zSvKl+BnrevHml3ZYtW5o377zzTunW9OnTS7vKi5SXXXZZ6dbKlSubN9UX\
# iPft21fabdq0qXnz1VdflW4leQICYgQIiBEgIEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCA\
# GAECYnr6bfhx48aVdgMDA82bo0ePlm5V3lAfO3Zs6daUKVNKu507dzZvqp/5HRwcLO0+//zz5s3r\
# r79eulX5LQuzZ88u3Vq1alVp9/zzzzdvDh06VLr11FNPlXajwRMQECNAQIwAATECBMQIEBAjQECM\
# AAExAgTECBAQI0BAjAABMQIExAgQENPTb8MvWbKktFu0aFHz5ssvvyzdWrBgQfNm+fLlpVs//vhj\
# affTTz81b26++ebSrYkTJ5Z269evb96MGTOmdOvkyZPNm/7+/tKtF198sbR79dVXmzfLli0r3Ury\
# BATECBAQI0BAjAABMQIExAgQECNAQIwAATECBMQIEBAjQECMAAExPf0y6h133FHaVT41u3Tp0tKt\
# Xbt2NW/2799furV169bSbtKkSc2bTz/9tHTrmWeeKe2effbZ5s20adNKt954443mze+//166de7c\
# udJu48aNzZvKS8dpnoCAGAECYgQIiBEgIEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAmJ5+\
# G/6PP/4o7WbOnNm8OXr0aOnWqVOnmjcrVqwo3XrvvfdKu/nz5zdvqm/eV3+rwJw5c5o3d999d+nW\
# DTfc0Ly56aabSrdeeuml0q6vr695c+jQodKtJE9AQIwAATECBMQIEBAjQECMAAExA

# %% [markdown]
# OK -- same data -- same number of epochs -- much much lower losses. Momentum -- speeds up learning -- the higher the momentum, ranged from `0.0` to `1.0` the faster the learning accelerates. Let's try a larger value.

# %%
optimizer = gluon.Trainer(params, 'sgd', {'learning_rate': 0.01, 'momentum': 0.9})
learning_steps, losses = learn(net, optimizer)
animate(learning_steps)
# Out:
# Loss: 0.14865300059318542
# Loss: 0.06458868831396103
# Loss: 0.02806341089308262
# Loss: 0.012193435803055763
# Loss: 0.005298033356666565
# Loss: 0.0023020224180072546
# Loss: 0.0010002354392781854
# Loss: 0.0004346092464402318
# Loss: 0.0001888431143015623
# Loss: 8.205253107007593e-05
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img40570ef709054480b1c09c5c3da70bee">
#     <br>
#     <input id="_anim_slider40570ef709054480b1c09c5c3da70bee" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim40570ef709054480b1c09c5c3da70bee.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim40570ef709054480b1c09c5c3da70bee.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select40570ef709054480b1c09c5c3da70bee" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img40570ef709054480b1c09c5c3da70bee";
#     var slider_id = "_anim_slider40570ef709054480b1c09c5c3da70bee";
#     var loop_select_id = "_anim_loop_select40570ef709054480b1c09c5c3da70bee";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCw
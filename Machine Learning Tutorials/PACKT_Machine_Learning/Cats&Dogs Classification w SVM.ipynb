# %% [markdown]
# ## Classifying images using SVM
# ### Import the digit image dataset

# %%
import numpy as np 
import sklearn as sk
import os
from PIL import Image 
from PIL import ImageFilter
from sklearn.svm import SVC

# %%
#get full dataset
train_images = [i for i in os.listdir('train')] 
print(train_images[0])

test_images = [i for i in os.listdir('test1')]
print(test_images[0])
# Out:
# cat.0.jpg
# 1.jpg

# %%
#We create a variable labels to store the labels
labels=[]
for i in train_images:
        if 'dog' in i:
            labels.append(1)
        else:
            labels.append(0)

# %% [markdown]
# #### We then extract the features from the images using the pillow library
# #### We then train the svm model

# %%
features=[]
pixel_value=0

#Here we are using the default RBF kernel as it took less
#time on the training data 

clf =  SVC()
#clf= SVC(kernel='linear')
#clf= SVC(kernel='poly')

for i in train_images:
    im = Image.open('train/'+i).convert('L')
    size=64,64

    im = im.resize(size, Image.ANTIALIAS)
    im =im.filter(ImageFilter.FIND_EDGES)
    pixel_value=im.histogram() 
    features.append(pixel_value)

#Training the svm model
clf = clf.fit(features,labels)
# Out:
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\1190076120.py:15: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.LANCZOS)

# %%
results=[]
total=0

for i in train_images[0:100]:
    im = Image.open('train/'+i).convert('L')
    size=64,64
    im = im.resize(size, Image.ANTIALIAS)
    im =im.filter(ImageFilter.FIND_EDGES)
    pixel_value=im.histogram() 
    x = clf.predict([pixel_value])
    results.append(x[0])  

print("Length",len(results))

total=np.sum(np.logical_and(labels[0:100],results))

print("Accuracy:",total,"/",len(results),"* 100 =","{0:.3f}".format(total/len(results)*100),"%")
# Out:
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# Length 100
# Accuracy: 0 / 100 * 100 = 0.000 %
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\3837583808.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)

# %%
results=[]

for i in test_images[0:5]:
    print(i)
    im = Image.open('test1/'+i).convert('L')
    size=64,64
    im = im.resize(size, Image.ANTIALIAS)
    im =im.filter(ImageFilter.FIND_EDGES)
    pixel_value=im.histogram() 
    x = clf.predict([pixel_value])
    
    print(x)
    results.append(x)  

print("Length",len(results))
# Out:
# 1.jpg
# [1]
# 10.jpg
# [0]
# 100.jpg
# [0]
# 1000.jpg
# [1]
# 10000.jpg
# [1]
# Length 5
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\2384407955.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\2384407955.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\2384407955.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\2384407955.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)
# C:\Users\Rahul Mitra\AppData\Local\Temp\ipykernel_34604\2384407955.py:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(size, Image.ANTIALIAS)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#Model predicted it to be a dog
img=mpimg.imread('test1/10964.jpg')
imgplot = plt.imshow(img)

# %%
#Model predicted it to be a dog
img=mpimg.imread('test1/10167.jpg')
imgplot = plt.imshow(img)

# %%
#Model pridected it to be a cat
img=mpimg.imread('test1/6015.jpg')
imgplot = plt.imshow(img)
